# %%
import numpy as np
#!pip install numpy
from tensorflow.keras.utils import to_categorical
import os
from PIL import Image
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import cv2

def mirror_augmentation(image):
    # Initialize an array to store augmented images
    augmented_images = []

    # Original Image
    augmented_images.append(image)

    # Mirror horizontally
    horizontal_mirror = cv2.flip(image, 1)
    augmented_images.append(horizontal_mirror)

    # Mirror vertically
    vertical_mirror = cv2.flip(image, 0)
    augmented_images.append(vertical_mirror)

    # Mirror both horizontally and vertically (diagonal flip)
    diagonal_mirror = cv2.flip(image, -1)
    augmented_images.append(diagonal_mirror)

    return augmented_images

# Path to the folder containing images
#folder_path = "/content/drive/MyDrive/dataset/not_damaged"
folder_path = "/content/drive/MyDrive/dataset/slightly_damaged"


# Output folder for augmented images
#output_folder = "/content/drive/MyDrive/dataset/not_damaged"
output_folder = "/content/drive/MyDrive/dataset/slightly_damaged"

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through each file in the folder
for filename in os.listdir(folder_path):
    # Check if the file is an image
    if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg"):
        # Read the image
        image_path = os.path.join(folder_path, filename)
        image = cv2.imread(image_path)

        # Check if the image is loaded successfully
        if image is not None:
            # Perform augmentation
            augmented_images = mirror_augmentation(image)

            # Save augmented images
            base_name = os.path.splitext(filename)[0]
            for idx, augmented_image in enumerate(augmented_images):
                output_path = os.path.join(output_folder, f"{base_name}_augmented_{idx}.jpg")
                cv2.imwrite(output_path, augmented_image)
        else:
            print(f"Error: Unable to read {filename}")

print("Augmentation completed.")"""
# Out:
# 'import os\nimport cv2\n\ndef mirror_augmentation(image):\n    # Initialize an array to store augmented images\n    augmented_images = []\n\n    # Original Image\n    augmented_images.append(image)\n\n    # Mirror horizontally\n    horizontal_mirror = cv2.flip(image, 1)\n    augmented_images.append(horizontal_mirror)\n\n    # Mirror vertically\n    vertical_mirror = cv2.flip(image, 0)\n    augmented_images.append(vertical_mirror)\n\n    # Mirror both horizontally and vertically (diagonal flip)\n    diagonal_mirror = cv2.flip(image, -1)\n    augmented_images.append(diagonal_mirror)\n\n    return augmented_images\n\n# Path to the folder containing images\n#folder_path = "/content/drive/MyDrive/dataset/not_damaged"\nfolder_path = "/content/drive/MyDrive/dataset/slightly_damaged"\n\n\n# Output folder for augmented images\n#output_folder = "/content/drive/MyDrive/dataset/not_damaged"\noutput_folder = "/content/drive/MyDrive/dataset/slightly_damaged"\n\n# Create the output folder if it doesn\'t exist\nif not os.path.exists(output_folder):\n    os.makedirs(output_folder)\n\n# Iterate through each file in the folder\nfor filename in os.listdir(folder_path):\n    # Check if the file is an image\n    if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg"):\n        # Read the image\n        image_path = os.path.join(folder_path, filename)\n        image = cv2.imread(image_path)\n\n        # Check if the image is loaded successfully\n        if image is not None:\n            # Perform augmentation\n            augmented_images = mirror_augmentation(image)\n\n            # Save augmented images\n            base_name = os.path.splitext(filename)[0]\n            for idx, augmented_image in enumerate(augmented_images):\n                output_path = os.path.join(output_folder, f"{base_name}_augmented_{idx}.jpg")\n                cv2.imwrite(output_path, augmented_image)\n        else:\n            print(f"Error: Unable to read {filename}")\n\nprint("Augmentation completed.")'

# %%
import os
import numpy as np
from PIL import Image

# Define the Dataset Directory
dataset_dir = "/content/drive/MyDrive/dataset/"

# List to store image paths and corresponding labels
image_paths = []
labels = []

# Iterate through each class folder
for class_label in os.listdir(dataset_dir):
    class_dir = os.path.join(dataset_dir, class_label)

    # Iterate through each image in the class folder
    for image_name in os.listdir(class_dir):
        # Read image path
        image_path = os.path.join(class_dir, image_name)

        # Open and preprocess image
        image = Image.open(image_path)
        # Perform preprocessing (e.g., resize, normalize)
        # image = image.resize((desired_width, desired_height))
        # image = np.array(image) / 255.0  # Normalize pixel values to [0, 1]

        # Append image path and label to lists
        image_paths.append(image_path)
        labels.append(class_label)  # Assuming class labels are folder names

# Convert labels to numeric format (e.g., using LabelEncoder)
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(labels)

# Convert image paths to NumPy array (optional)
X = np.array(image_paths)

# Sanity check: print number of images and labels
print("Number of Images:", len(X))
print("Number of Labels:", len(y))
# Out:
# Number of Images: 3929
# Number of Labels: 3929

# %%
# Define the number of samples to visualize per class
num_samples_per_class = 3

# Visualize a few images from each class
fig, axes = plt.subplots(len(np.unique(y)), num_samples_per_class, figsize=(10, 6))

for i, class_label in enumerate(np.unique(y)):
    class_indices = np.where(y == class_label)[0]
    sampled_indices = np.random.choice(class_indices, size=num_samples_per_class, replace=False)

    for j, idx in enumerate(sampled_indices):
        image_path = X[idx]  # Get image path from X
        image = Image.open(image_path)
        axes[i, j].imshow(image)
        axes[i, j].axis('off')
        axes[i, j].set_title(class_label)

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img

# Define desired image dimensions
image_width, image_height = 150, 150
s
# Preprocess images
X_images_processed = []
for image_path in image_paths:
    image = Image.open(image_path)
    image = image.resize((image_width, image_height))  # Resize image
    image_array = img_to_array(image)  # Convert image to array
    image_array /= 255.0  # Normalize pixel values to [0, 1]
    X_images_processed.append(image_array)

X_processed = np.array(X_images_processed)

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into training, validation, and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Define the CNN model architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(image_height, image_width, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(3, activation='softmax')  # Assuming 3 classes for classification
])

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=500, validation_data=(X_val, y_val))
# Out:
# Epoch 1/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.7609 - accuracy: 0.7571 - val_loss: 0.6163 - val_accuracy: 0.8000
# Epoch 2/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.6424 - accuracy: 0.7822 - val_loss: 0.5570 - val_accuracy: 0.8254
# Epoch 3/500
# 89/89 [==============================] - 112s 1s/step - loss: 0.5836 - accuracy: 0.8034 - val_loss: 0.4648 - val_accuracy: 0.8381
# Epoch 4/500
# 89/89 [==============================] - 112s 1s/step - loss: 0.4961 - accuracy: 0.8232 - val_loss: 0.4887 - val_accuracy: 0.8444
# Epoch 5/500
# 89/89 [==============================] - 111s 1s/step - loss: 0.4174 - accuracy: 0.8487 - val_loss: 0.3997 - val_accuracy: 0.8444
# Epoch 6/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.3415 - accuracy: 0.8745 - val_loss: 0.4303 - val_accuracy: 0.8540
# Epoch 7/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.2998 - accuracy: 0.8876 - val_loss: 0.3990 - val_accuracy: 0.8984
# Epoch 8/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.2139 - accuracy: 0.9250 - val_loss: 0.3600 - val_accuracy: 0.9048
# Epoch 9/500
# 89/89 [==============================] - 117s 1s/step - loss: 0.1715 - accuracy: 0.9466 - val_loss: 0.3859 - val_accuracy: 0.9111
# Epoch 10/500
# 89/89 [==============================] - 111s 1s/step - loss: 0.1551 - accuracy: 0.9530 - val_loss: 0.4859 - val_accuracy: 0.9238
# Epoch 11/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.1430 - accuracy: 0.9593 - val_loss: 0.4103 - val_accuracy: 0.8984
# Epoch 12/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.1485 - accuracy: 0.9583 - val_loss: 0.5538 - val_accuracy: 0.9175
# Epoch 13/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.1312 - accuracy: 0.9632 - val_loss: 0.4737 - val_accuracy: 0.9143
# Epoch 14/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.1014 - accuracy: 0.9696 - val_loss: 0.4109 - val_accuracy: 0.9111
# Epoch 15/500
# 89/89 [==============================] - 118s 1s/step - loss: 0.1170 - accuracy: 0.9604 - val_loss: 0.6910 - val_accuracy: 0.9206
# Epoch 16/500
# 89/89 [==============================] - 111s 1s/step - loss: 0.1032 - accuracy: 0.9710 - val_loss: 0.3854 - val_accuracy: 0.9143
# Epoch 17/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0905 - accuracy: 0.9721 - val_loss: 0.4039 - val_accuracy: 0.9270
# Epoch 18/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0803 - accuracy: 0.9767 - val_loss: 0.3874 - val_accuracy: 0.9302
# Epoch 19/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0809 - accuracy: 0.9774 - val_loss: 0.4091 - val_accuracy: 0.9302
# Epoch 20/500
# 89/89 [==============================] - 114s 1s/step - loss: 0.0822 - accuracy: 0.9760 - val_loss: 0.4345 - val_accuracy: 0.9175
# Epoch 21/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0777 - accuracy: 0.9749 - val_loss: 0.4366 - val_accuracy: 0.9270
# Epoch 22/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0747 - accuracy: 0.9774 - val_loss: 0.4279 - val_accuracy: 0.9206
# Epoch 23/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0711 - accuracy: 0.9767 - val_loss: 0.4197 - val_accuracy: 0.9365
# Epoch 24/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0703 - accuracy: 0.9770 - val_loss: 0.4457 - val_accuracy: 0.9175
# Epoch 25/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0714 - accuracy: 0.9774 - val_loss: 0.4187 - val_accuracy: 0.9302
# Epoch 26/500
# 89/89 [==============================] - 111s 1s/step - loss: 0.0712 - accuracy: 0.9763 - val_loss: 0.4365 - val_accuracy: 0.9238
# Epoch 27/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0713 - accuracy: 0.9777 - val_loss: 0.4556 - val_accuracy: 0.9270
# Epoch 28/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0711 - accuracy: 0.9760 - val_loss: 0.4789 - val_accuracy: 0.9206
# Epoch 29/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0754 - accuracy: 0.9752 - val_loss: 0.4235 - val_accuracy: 0.9206
# Epoch 30/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0778 - accuracy: 0.9721 - val_loss: 0.3514 - val_accuracy: 0.9333
# Epoch 31/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0729 - accuracy: 0.9752 - val_loss: 0.4030 - val_accuracy: 0.9270
# Epoch 32/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0872 - accuracy: 0.9710 - val_loss: 0.5762 - val_accuracy: 0.9206
# Epoch 33/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0738 - accuracy: 0.9745 - val_loss: 0.5081 - val_accuracy: 0.9048
# Epoch 34/500
# 89/89 [==============================] - 112s 1s/step - loss: 0.0692 - accuracy: 0.9777 - val_loss: 0.5027 - val_accuracy: 0.9175
# Epoch 35/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.2599 - accuracy: 0.9165 - val_loss: 0.4400 - val_accuracy: 0.8921
# Epoch 36/500
# 89/89 [==============================] - 111s 1s/step - loss: 0.1737 - accuracy: 0.9480 - val_loss: 0.3635 - val_accuracy: 0.8825
# Epoch 37/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.1023 - accuracy: 0.9692 - val_loss: 0.4023 - val_accuracy: 0.9175
# Epoch 38/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0806 - accuracy: 0.9742 - val_loss: 0.3916 - val_accuracy: 0.9111
# Epoch 39/500
# 89/89 [==============================] - 104s 1s/step - loss: 0.0707 - accuracy: 0.9763 - val_loss: 0.4396 - val_accuracy: 0.9111
# Epoch 40/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0689 - accuracy: 0.9774 - val_loss: 0.4459 - val_accuracy: 0.9079
# Epoch 41/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0668 - accuracy: 0.9760 - val_loss: 0.4632 - val_accuracy: 0.9048
# Epoch 42/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0675 - accuracy: 0.9760 - val_loss: 0.4487 - val_accuracy: 0.9175
# Epoch 43/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0681 - accuracy: 0.9781 - val_loss: 0.5500 - val_accuracy: 0.9111
# Epoch 44/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0682 - accuracy: 0.9756 - val_loss: 0.5129 - val_accuracy: 0.9238
# Epoch 45/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0683 - accuracy: 0.9770 - val_loss: 0.5143 - val_accuracy: 0.9016
# Epoch 46/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0655 - accuracy: 0.9770 - val_loss: 0.5293 - val_accuracy: 0.9206
# Epoch 47/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0650 - accuracy: 0.9760 - val_loss: 0.5295 - val_accuracy: 0.9111
# Epoch 48/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0657 - accuracy: 0.9774 - val_loss: 0.5356 - val_accuracy: 0.9206
# Epoch 49/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0636 - accuracy: 0.9777 - val_loss: 0.5519 - val_accuracy: 0.9175
# Epoch 50/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0635 - accuracy: 0.9774 - val_loss: 0.5445 - val_accuracy: 0.9143
# Epoch 51/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0654 - accuracy: 0.9774 - val_loss: 0.5640 - val_accuracy: 0.9143
# Epoch 52/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0660 - accuracy: 0.9760 - val_loss: 0.5420 - val_accuracy: 0.9143
# Epoch 53/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0644 - accuracy: 0.9784 - val_loss: 0.5185 - val_accuracy: 0.9175
# Epoch 54/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0622 - accuracy: 0.9767 - val_loss: 0.5559 - val_accuracy: 0.9143
# Epoch 55/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0635 - accuracy: 0.9774 - val_loss: 0.6095 - val_accuracy: 0.9175
# Epoch 56/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0651 - accuracy: 0.9770 - val_loss: 0.5679 - val_accuracy: 0.9175
# Epoch 57/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0647 - accuracy: 0.9788 - val_loss: 0.5235 - val_accuracy: 0.9079
# Epoch 58/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0657 - accuracy: 0.9781 - val_loss: 0.5619 - val_accuracy: 0.9143
# Epoch 59/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0644 - accuracy: 0.9781 - val_loss: 0.5883 - val_accuracy: 0.9175
# Epoch 60/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0617 - accuracy: 0.9781 - val_loss: 0.5420 - val_accuracy: 0.9238
# Epoch 61/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0647 - accuracy: 0.9781 - val_loss: 0.6326 - val_accuracy: 0.9175
# Epoch 62/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0634 - accuracy: 0.9770 - val_loss: 0.6619 - val_accuracy: 0.9143
# Epoch 63/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0629 - accuracy: 0.9781 - val_loss: 0.6810 - val_accuracy: 0.9048
# Epoch 64/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0627 - accuracy: 0.9791 - val_loss: 0.5850 - val_accuracy: 0.9206
# Epoch 65/500
# 89/89 [==============================] - 102s 1s/step - loss: 0.0617 - accuracy: 0.9788 - val_loss: 0.6865 - val_accuracy: 0.8984
# Epoch 66/500
# 89/89 [==============================] - 103s 1s/step - loss: 0.0636 - accuracy: 0.9791 - val_loss: 0.6130 - val_accuracy: 0.9270
# Epoch 67/500
# 89/89 [==============================] - 104s 1s/step - loss: 0.0648 - accuracy: 0.9781 - val_loss: 0.6869 - val_accuracy: 0.9143
# Epoch 68/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0638 - accuracy: 0.9777 - val_loss: 0.6486 - val_accuracy: 0.9111
# Epoch 69/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0606 - accuracy: 0.9777 - val_loss: 0.6214 - val_accuracy: 0.9143
# Epoch 70/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0606 - accuracy: 0.9777 - val_loss: 0.6092 - val_accuracy: 0.9048
# Epoch 71/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0596 - accuracy: 0.9770 - val_loss: 0.6249 - val_accuracy: 0.9143
# Epoch 72/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0605 - accuracy: 0.9781 - val_loss: 0.6655 - val_accuracy: 0.9143
# Epoch 73/500
# 89/89 [==============================] - 101s 1s/step - loss: 0.0615 - accuracy: 0.9784 - val_loss: 0.7175 - val_accuracy: 0.9175
# Epoch 74/500
# 89/89 [==============================] - 104s 1s/step - loss: 0.0953 - accuracy: 0.9710 - val_loss: 0.7307 - val_accuracy: 0.9048
# Epoch 75/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0925 - accuracy: 0.9710 - val_loss: 0.7671 - val_accuracy: 0.9016
# Epoch 76/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0720 - accuracy: 0.9774 - val_loss: 0.8278 - val_accuracy: 0.9111
# Epoch 77/500
# 89/89 [==============================] - 102s 1s/step - loss: 0.0653 - accuracy: 0.9763 - val_loss: 0.9384 - val_accuracy: 0.9079
# Epoch 78/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0644 - accuracy: 0.9777 - val_loss: 0.9733 - val_accuracy: 0.8984
# Epoch 79/500
# 89/89 [==============================] - 101s 1s/step - loss: 0.0637 - accuracy: 0.9784 - val_loss: 0.9530 - val_accuracy: 0.9111
# Epoch 80/500
# 89/89 [==============================] - 102s 1s/step - loss: 0.0605 - accuracy: 0.9777 - val_loss: 0.9434 - val_accuracy: 0.9079
# Epoch 81/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0605 - accuracy: 0.9784 - val_loss: 0.9721 - val_accuracy: 0.9048
# Epoch 82/500
# 89/89 [==============================] - 103s 1s/step - loss: 0.0594 - accuracy: 0.9788 - val_loss: 0.9189 - val_accuracy: 0.9048
# Epoch 83/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0575 - accuracy: 0.9784 - val_loss: 0.8426 - val_accuracy: 0.9016
# Epoch 84/500
# 89/89 [==============================] - 102s 1s/step - loss: 0.0582 - accuracy: 0.9784 - val_loss: 0.9324 - val_accuracy: 0.9143
# Epoch 85/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0579 - accuracy: 0.9781 - val_loss: 0.9939 - val_accuracy: 0.9079
# Epoch 86/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0585 - accuracy: 0.9791 - val_loss: 0.9987 - val_accuracy: 0.9111
# Epoch 87/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0575 - accuracy: 0.9788 - val_loss: 0.9620 - val_accuracy: 0.9111
# Epoch 88/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0590 - accuracy: 0.9784 - val_loss: 0.9555 - val_accuracy: 0.9048
# Epoch 89/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0601 - accuracy: 0.9781 - val_loss: 0.9230 - val_accuracy: 0.9111
# Epoch 90/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0576 - accuracy: 0.9788 - val_loss: 0.9121 - val_accuracy: 0.9143
# Epoch 91/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0581 - accuracy: 0.9784 - val_loss: 0.8762 - val_accuracy: 0.9079
# Epoch 92/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0597 - accuracy: 0.9788 - val_loss: 0.9483 - val_accuracy: 0.9048
# Epoch 93/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0585 - accuracy: 0.9788 - val_loss: 0.8995 - val_accuracy: 0.9079
# Epoch 94/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0577 - accuracy: 0.9788 - val_loss: 0.8880 - val_accuracy: 0.9079
# Epoch 95/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0557 - accuracy: 0.9784 - val_loss: 0.9260 - val_accuracy: 0.9079
# Epoch 96/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0565 - accuracy: 0.9784 - val_loss: 0.9442 - val_accuracy: 0.9175
# Epoch 97/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0589 - accuracy: 0.9777 - val_loss: 0.8917 - val_accuracy: 0.9175
# Epoch 98/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0572 - accuracy: 0.9781 - val_loss: 0.8831 - val_accuracy: 0.9206
# Epoch 99/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0576 - accuracy: 0.9784 - val_loss: 1.0204 - val_accuracy: 0.9111
# Epoch 100/500
# 89/89 [==============================] - 112s 1s/step - loss: 0.0592 - accuracy: 0.9784 - val_loss: 0.8572 - val_accuracy: 0.9206
# Epoch 101/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0569 - accuracy: 0.9791 - val_loss: 0.8961 - val_accuracy: 0.9206
# Epoch 102/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0569 - accuracy: 0.9788 - val_loss: 0.9442 - val_accuracy: 0.9143
# Epoch 103/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0570 - accuracy: 0.9784 - val_loss: 0.9938 - val_accuracy: 0.9143
# Epoch 104/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0575 - accuracy: 0.9791 - val_loss: 0.8977 - val_accuracy: 0.9143
# Epoch 105/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0569 - accuracy: 0.9788 - val_loss: 0.9290 - val_accuracy: 0.9206
# Epoch 106/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0735 - accuracy: 0.9749 - val_loss: 1.1194 - val_accuracy: 0.9016
# Epoch 107/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0673 - accuracy: 0.9781 - val_loss: 1.0535 - val_accuracy: 0.9016
# Epoch 108/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0614 - accuracy: 0.9791 - val_loss: 0.9600 - val_accuracy: 0.9016
# Epoch 109/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0578 - accuracy: 0.9791 - val_loss: 0.8319 - val_accuracy: 0.9143
# Epoch 110/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0567 - accuracy: 0.9788 - val_loss: 0.9237 - val_accuracy: 0.9206
# Epoch 111/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0560 - accuracy: 0.9784 - val_loss: 0.9723 - val_accuracy: 0.9143
# Epoch 112/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0579 - accuracy: 0.9791 - val_loss: 0.8873 - val_accuracy: 0.9143
# Epoch 113/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0556 - accuracy: 0.9788 - val_loss: 0.8924 - val_accuracy: 0.9206
# Epoch 114/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0570 - accuracy: 0.9784 - val_loss: 0.9533 - val_accuracy: 0.9175
# Epoch 115/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0570 - accuracy: 0.9795 - val_loss: 0.8491 - val_accuracy: 0.9175
# Epoch 116/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0586 - accuracy: 0.9788 - val_loss: 0.8258 - val_accuracy: 0.9143
# Epoch 117/500
# 89/89 [==============================] - 112s 1s/step - loss: 0.0563 - accuracy: 0.9788 - val_loss: 0.9961 - val_accuracy: 0.9175
# Epoch 118/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0553 - accuracy: 0.9788 - val_loss: 0.9122 - val_accuracy: 0.9143
# Epoch 119/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0554 - accuracy: 0.9781 - val_loss: 0.9668 - val_accuracy: 0.9143
# Epoch 120/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0556 - accuracy: 0.9795 - val_loss: 0.9053 - val_accuracy: 0.9206
# Epoch 121/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0546 - accuracy: 0.9791 - val_loss: 0.9081 - val_accuracy: 0.9175
# Epoch 122/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0555 - accuracy: 0.9784 - val_loss: 0.9450 - val_accuracy: 0.9143
# Epoch 123/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0557 - accuracy: 0.9791 - val_loss: 0.9580 - val_accuracy: 0.9111
# Epoch 124/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0562 - accuracy: 0.9795 - val_loss: 0.9221 - val_accuracy: 0.9206
# Epoch 125/500
# 89/89 [==============================] - 112s 1s/step - loss: 0.0554 - accuracy: 0.9795 - val_loss: 0.9455 - val_accuracy: 0.9175
# Epoch 126/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0550 - accuracy: 0.9777 - val_loss: 1.0542 - val_accuracy: 0.9206
# Epoch 127/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0565 - accuracy: 0.9791 - val_loss: 0.9166 - val_accuracy: 0.9079
# Epoch 128/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0552 - accuracy: 0.9788 - val_loss: 0.9898 - val_accuracy: 0.9206
# Epoch 129/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0551 - accuracy: 0.9795 - val_loss: 0.9512 - val_accuracy: 0.9143
# Epoch 130/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0540 - accuracy: 0.9791 - val_loss: 0.9581 - val_accuracy: 0.9111
# Epoch 131/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0546 - accuracy: 0.9788 - val_loss: 0.9818 - val_accuracy: 0.9143
# Epoch 132/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0557 - accuracy: 0.9791 - val_loss: 0.8944 - val_accuracy: 0.9111
# Epoch 133/500
# 89/89 [==============================] - 112s 1s/step - loss: 0.0569 - accuracy: 0.9795 - val_loss: 1.0847 - val_accuracy: 0.9238
# Epoch 134/500
# 89/89 [==============================] - 111s 1s/step - loss: 0.0563 - accuracy: 0.9791 - val_loss: 0.9063 - val_accuracy: 0.9206
# Epoch 135/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0557 - accuracy: 0.9784 - val_loss: 0.9402 - val_accuracy: 0.9206
# Epoch 136/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0565 - accuracy: 0.9781 - val_loss: 1.0568 - val_accuracy: 0.9238
# Epoch 137/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0548 - accuracy: 0.9784 - val_loss: 0.8773 - val_accuracy: 0.9175
# Epoch 138/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0558 - accuracy: 0.9795 - val_loss: 1.0706 - val_accuracy: 0.9206
# Epoch 139/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0901 - accuracy: 0.9728 - val_loss: 0.8956 - val_accuracy: 0.9111
# Epoch 140/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0802 - accuracy: 0.9742 - val_loss: 0.8154 - val_accuracy: 0.9079
# Epoch 141/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0583 - accuracy: 0.9784 - val_loss: 0.7812 - val_accuracy: 0.9238
# Epoch 142/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0604 - accuracy: 0.9781 - val_loss: 0.8167 - val_accuracy: 0.9143
# Epoch 143/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0584 - accuracy: 0.9788 - val_loss: 0.8119 - val_accuracy: 0.9175
# Epoch 144/500
# 89/89 [==============================] - 111s 1s/step - loss: 0.0558 - accuracy: 0.9788 - val_loss: 0.8026 - val_accuracy: 0.9143
# Epoch 145/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0545 - accuracy: 0.9791 - val_loss: 0.7825 - val_accuracy: 0.9206
# Epoch 146/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0546 - accuracy: 0.9788 - val_loss: 0.7901 - val_accuracy: 0.9238
# Epoch 147/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0537 - accuracy: 0.9788 - val_loss: 0.8259 - val_accuracy: 0.9238
# Epoch 148/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0545 - accuracy: 0.9795 - val_loss: 0.7997 - val_accuracy: 0.9238
# Epoch 149/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0541 - accuracy: 0.9788 - val_loss: 0.7632 - val_accuracy: 0.9238
# Epoch 150/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0550 - accuracy: 0.9791 - val_loss: 0.8384 - val_accuracy: 0.9238
# Epoch 151/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0553 - accuracy: 0.9784 - val_loss: 0.7682 - val_accuracy: 0.9238
# Epoch 152/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0545 - accuracy: 0.9791 - val_loss: 0.7449 - val_accuracy: 0.9238
# Epoch 153/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0544 - accuracy: 0.9791 - val_loss: 0.7621 - val_accuracy: 0.9238
# Epoch 154/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0544 - accuracy: 0.9791 - val_loss: 0.7727 - val_accuracy: 0.9238
# Epoch 155/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0535 - accuracy: 0.9784 - val_loss: 0.8189 - val_accuracy: 0.9270
# Epoch 156/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0537 - accuracy: 0.9795 - val_loss: 0.8079 - val_accuracy: 0.9270
# Epoch 157/500
# 89/89 [==============================] - 104s 1s/step - loss: 0.0538 - accuracy: 0.9795 - val_loss: 0.8173 - val_accuracy: 0.9270
# Epoch 158/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0546 - accuracy: 0.9788 - val_loss: 0.7517 - val_accuracy: 0.9302
# Epoch 159/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0539 - accuracy: 0.9788 - val_loss: 0.8020 - val_accuracy: 0.9143
# Epoch 160/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0541 - accuracy: 0.9784 - val_loss: 0.7992 - val_accuracy: 0.9270
# Epoch 161/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0544 - accuracy: 0.9788 - val_loss: 0.7907 - val_accuracy: 0.9238
# Epoch 162/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0539 - accuracy: 0.9795 - val_loss: 0.7544 - val_accuracy: 0.9270
# Epoch 163/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0545 - accuracy: 0.9788 - val_loss: 0.7401 - val_accuracy: 0.9238
# Epoch 164/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0552 - accuracy: 0.9795 - val_loss: 0.7863 - val_accuracy: 0.9270
# Epoch 165/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0550 - accuracy: 0.9791 - val_loss: 0.7919 - val_accuracy: 0.9206
# Epoch 166/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0550 - accuracy: 0.9784 - val_loss: 0.7871 - val_accuracy: 0.9302
# Epoch 167/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0558 - accuracy: 0.9784 - val_loss: 0.7351 - val_accuracy: 0.9206
# Epoch 168/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0545 - accuracy: 0.9795 - val_loss: 0.7676 - val_accuracy: 0.9270
# Epoch 169/500
# 89/89 [==============================] - 113s 1s/step - loss: 0.0537 - accuracy: 0.9791 - val_loss: 0.7378 - val_accuracy: 0.9238
# Epoch 170/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0536 - accuracy: 0.9791 - val_loss: 0.8075 - val_accuracy: 0.9333
# Epoch 171/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0539 - accuracy: 0.9795 - val_loss: 0.7716 - val_accuracy: 0.9238
# Epoch 172/500
# 89/89 [==============================] - 111s 1s/step - loss: 0.0555 - accuracy: 0.9791 - val_loss: 0.8527 - val_accuracy: 0.9206
# Epoch 173/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.2083 - accuracy: 0.9480 - val_loss: 0.7583 - val_accuracy: 0.8603
# Epoch 174/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.2091 - accuracy: 0.9466 - val_loss: 1.0582 - val_accuracy: 0.9206
# Epoch 175/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0851 - accuracy: 0.9745 - val_loss: 1.1540 - val_accuracy: 0.9079
# Epoch 176/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0622 - accuracy: 0.9784 - val_loss: 1.1235 - val_accuracy: 0.9175
# Epoch 177/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0566 - accuracy: 0.9791 - val_loss: 1.1757 - val_accuracy: 0.9111
# Epoch 178/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0615 - accuracy: 0.9784 - val_loss: 1.0215 - val_accuracy: 0.9111
# Epoch 179/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0564 - accuracy: 0.9795 - val_loss: 1.1047 - val_accuracy: 0.9143
# Epoch 180/500
# 89/89 [==============================] - 104s 1s/step - loss: 0.0555 - accuracy: 0.9791 - val_loss: 1.1605 - val_accuracy: 0.9143
# Epoch 181/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0542 - accuracy: 0.9788 - val_loss: 1.2056 - val_accuracy: 0.9143
# Epoch 182/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0543 - accuracy: 0.9791 - val_loss: 1.1013 - val_accuracy: 0.9143
# Epoch 183/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0543 - accuracy: 0.9788 - val_loss: 1.1441 - val_accuracy: 0.9175
# Epoch 184/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0539 - accuracy: 0.9791 - val_loss: 1.1664 - val_accuracy: 0.9143
# Epoch 185/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0539 - accuracy: 0.9791 - val_loss: 1.2135 - val_accuracy: 0.9175
# Epoch 186/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0551 - accuracy: 0.9788 - val_loss: 1.1390 - val_accuracy: 0.9143
# Epoch 187/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0537 - accuracy: 0.9788 - val_loss: 1.1957 - val_accuracy: 0.9143
# Epoch 188/500
# 89/89 [==============================] - 104s 1s/step - loss: 0.0540 - accuracy: 0.9795 - val_loss: 1.1629 - val_accuracy: 0.9143
# Epoch 189/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0534 - accuracy: 0.9795 - val_loss: 1.2487 - val_accuracy: 0.9206
# Epoch 190/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0539 - accuracy: 0.9795 - val_loss: 1.2285 - val_accuracy: 0.9143
# Epoch 191/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0537 - accuracy: 0.9791 - val_loss: 1.2614 - val_accuracy: 0.9175
# Epoch 192/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0541 - accuracy: 0.9795 - val_loss: 1.2059 - val_accuracy: 0.9175
# Epoch 193/500
# 89/89 [==============================] - 103s 1s/step - loss: 0.0542 - accuracy: 0.9795 - val_loss: 1.2447 - val_accuracy: 0.9175
# Epoch 194/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0538 - accuracy: 0.9791 - val_loss: 1.1859 - val_accuracy: 0.9175
# Epoch 195/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0552 - accuracy: 0.9788 - val_loss: 1.2849 - val_accuracy: 0.9175
# Epoch 196/500
# 89/89 [==============================] - 104s 1s/step - loss: 0.0542 - accuracy: 0.9795 - val_loss: 1.1597 - val_accuracy: 0.9270
# Epoch 197/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0547 - accuracy: 0.9791 - val_loss: 1.2930 - val_accuracy: 0.9206
# Epoch 198/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0537 - accuracy: 0.9784 - val_loss: 1.2474 - val_accuracy: 0.9175
# Epoch 199/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0536 - accuracy: 0.9791 - val_loss: 1.2450 - val_accuracy: 0.9238
# Epoch 200/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0537 - accuracy: 0.9791 - val_loss: 1.2490 - val_accuracy: 0.9206
# Epoch 201/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0542 - accuracy: 0.9791 - val_loss: 1.3204 - val_accuracy: 0.9206
# Epoch 202/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0538 - accuracy: 0.9791 - val_loss: 1.3374 - val_accuracy: 0.9302
# Epoch 203/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0542 - accuracy: 0.9784 - val_loss: 1.3047 - val_accuracy: 0.9175
# Epoch 204/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0535 - accuracy: 0.9795 - val_loss: 1.2754 - val_accuracy: 0.9175
# Epoch 205/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0540 - accuracy: 0.9791 - val_loss: 1.2931 - val_accuracy: 0.9175
# Epoch 206/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0537 - accuracy: 0.9784 - val_loss: 1.2284 - val_accuracy: 0.9111
# Epoch 207/500
# 89/89 [==============================] - 104s 1s/step - loss: 0.0901 - accuracy: 0.9749 - val_loss: 1.1971 - val_accuracy: 0.9175
# Epoch 208/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0629 - accuracy: 0.9763 - val_loss: 1.1025 - val_accuracy: 0.9206
# Epoch 209/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0642 - accuracy: 0.9767 - val_loss: 1.4436 - val_accuracy: 0.9206
# Epoch 210/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0908 - accuracy: 0.9788 - val_loss: 0.9478 - val_accuracy: 0.9175
# Epoch 211/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0551 - accuracy: 0.9795 - val_loss: 0.9607 - val_accuracy: 0.9175
# Epoch 212/500
# 89/89 [==============================] - 102s 1s/step - loss: 0.0548 - accuracy: 0.9788 - val_loss: 1.0231 - val_accuracy: 0.9238
# Epoch 213/500
# 89/89 [==============================] - 103s 1s/step - loss: 0.0543 - accuracy: 0.9788 - val_loss: 0.9762 - val_accuracy: 0.9206
# Epoch 214/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0539 - accuracy: 0.9784 - val_loss: 1.0549 - val_accuracy: 0.9175
# Epoch 215/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0541 - accuracy: 0.9791 - val_loss: 0.9995 - val_accuracy: 0.9175
# Epoch 216/500
# 89/89 [==============================] - 103s 1s/step - loss: 0.0551 - accuracy: 0.9788 - val_loss: 1.0396 - val_accuracy: 0.9206
# Epoch 217/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0540 - accuracy: 0.9791 - val_loss: 1.0157 - val_accuracy: 0.9175
# Epoch 218/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0538 - accuracy: 0.9791 - val_loss: 0.9950 - val_accuracy: 0.9143
# Epoch 219/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0540 - accuracy: 0.9784 - val_loss: 1.0314 - val_accuracy: 0.9175
# Epoch 220/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0539 - accuracy: 0.9788 - val_loss: 1.0532 - val_accuracy: 0.9206
# Epoch 221/500
# 89/89 [==============================] - 104s 1s/step - loss: 0.0536 - accuracy: 0.9791 - val_loss: 1.0509 - val_accuracy: 0.9206
# Epoch 222/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0536 - accuracy: 0.9781 - val_loss: 1.0065 - val_accuracy: 0.9206
# Epoch 223/500
# 89/89 [==============================] - 104s 1s/step - loss: 0.0536 - accuracy: 0.9791 - val_loss: 1.0887 - val_accuracy: 0.9206
# Epoch 224/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0534 - accuracy: 0.9791 - val_loss: 1.0857 - val_accuracy: 0.9206
# Epoch 225/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0540 - accuracy: 0.9781 - val_loss: 1.1118 - val_accuracy: 0.9206
# Epoch 226/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0543 - accuracy: 0.9784 - val_loss: 1.0376 - val_accuracy: 0.9206
# Epoch 227/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0533 - accuracy: 0.9784 - val_loss: 1.0517 - val_accuracy: 0.9206
# Epoch 228/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0532 - accuracy: 0.9791 - val_loss: 1.0627 - val_accuracy: 0.9206
# Epoch 229/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0539 - accuracy: 0.9788 - val_loss: 1.0902 - val_accuracy: 0.9206
# Epoch 230/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0535 - accuracy: 0.9788 - val_loss: 1.1092 - val_accuracy: 0.9206
# Epoch 231/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0535 - accuracy: 0.9795 - val_loss: 1.0855 - val_accuracy: 0.9175
# Epoch 232/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0533 - accuracy: 0.9784 - val_loss: 1.0761 - val_accuracy: 0.9175
# Epoch 233/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0536 - accuracy: 0.9784 - val_loss: 1.1005 - val_accuracy: 0.9175
# Epoch 234/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0531 - accuracy: 0.9781 - val_loss: 1.1038 - val_accuracy: 0.9206
# Epoch 235/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0533 - accuracy: 0.9788 - val_loss: 1.0930 - val_accuracy: 0.9206
# Epoch 236/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0531 - accuracy: 0.9795 - val_loss: 1.1854 - val_accuracy: 0.9206
# Epoch 237/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0538 - accuracy: 0.9784 - val_loss: 1.0806 - val_accuracy: 0.9175
# Epoch 238/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0532 - accuracy: 0.9795 - val_loss: 1.0203 - val_accuracy: 0.9206
# Epoch 239/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0525 - accuracy: 0.9784 - val_loss: 1.2568 - val_accuracy: 0.9206
# Epoch 240/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0658 - accuracy: 0.9777 - val_loss: 1.1499 - val_accuracy: 0.9143
# Epoch 241/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0569 - accuracy: 0.9784 - val_loss: 1.1248 - val_accuracy: 0.9238
# Epoch 242/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0544 - accuracy: 0.9788 - val_loss: 1.1331 - val_accuracy: 0.9270
# Epoch 243/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0536 - accuracy: 0.9795 - val_loss: 1.0820 - val_accuracy: 0.9238
# Epoch 244/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0534 - accuracy: 0.9791 - val_loss: 1.1952 - val_accuracy: 0.9270
# Epoch 245/500
# 89/89 [==============================] - 112s 1s/step - loss: 0.0537 - accuracy: 0.9791 - val_loss: 1.1579 - val_accuracy: 0.9238
# Epoch 246/500
# 89/89 [==============================] - 111s 1s/step - loss: 0.0532 - accuracy: 0.9791 - val_loss: 1.1973 - val_accuracy: 0.9270
# Epoch 247/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0530 - accuracy: 0.9784 - val_loss: 1.2437 - val_accuracy: 0.9270
# Epoch 248/500
# 89/89 [==============================] - 114s 1s/step - loss: 0.0530 - accuracy: 0.9784 - val_loss: 1.2345 - val_accuracy: 0.9238
# Epoch 249/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0536 - accuracy: 0.9781 - val_loss: 1.1870 - val_accuracy: 0.9238
# Epoch 250/500
# 89/89 [==============================] - 113s 1s/step - loss: 0.0531 - accuracy: 0.9791 - val_loss: 1.2012 - val_accuracy: 0.9238
# Epoch 251/500
# 89/89 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9791Epoch 252/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0590 - accuracy: 0.9788 - val_loss: 1.2524 - val_accuracy: 0.9111
# Epoch 253/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0550 - accuracy: 0.9784 - val_loss: 1.2526 - val_accuracy: 0.9206
# Epoch 254/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0540 - accuracy: 0.9781 - val_loss: 1.1715 - val_accuracy: 0.9175
# Epoch 255/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0538 - accuracy: 0.9781 - val_loss: 1.1745 - val_accuracy: 0.9238
# Epoch 256/500
# 89/89 [==============================] - 115s 1s/step - loss: 0.0531 - accuracy: 0.9788 - val_loss: 1.2072 - val_accuracy: 0.9238
# Epoch 257/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0535 - accuracy: 0.9795 - val_loss: 1.1997 - val_accuracy: 0.9206
# Epoch 258/500
# 89/89 [==============================] - 111s 1s/step - loss: 0.0530 - accuracy: 0.9795 - val_loss: 1.1500 - val_accuracy: 0.9206
# Epoch 259/500
# 89/89 [==============================] - 112s 1s/step - loss: 0.0541 - accuracy: 0.9791 - val_loss: 1.1379 - val_accuracy: 0.9143
# Epoch 260/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0534 - accuracy: 0.9788 - val_loss: 1.1277 - val_accuracy: 0.9175
# Epoch 261/500
# 89/89 [==============================] - 112s 1s/step - loss: 0.0530 - accuracy: 0.9791 - val_loss: 1.1621 - val_accuracy: 0.9238
# Epoch 262/500
# 89/89 [==============================] - 113s 1s/step - loss: 0.0529 - accuracy: 0.9781 - val_loss: 1.1499 - val_accuracy: 0.9238
# Epoch 263/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0529 - accuracy: 0.9784 - val_loss: 1.1057 - val_accuracy: 0.9206
# Epoch 264/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0547 - accuracy: 0.9781 - val_loss: 1.3047 - val_accuracy: 0.9175
# Epoch 265/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0532 - accuracy: 0.9788 - val_loss: 1.2172 - val_accuracy: 0.9238
# Epoch 266/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0621 - accuracy: 0.9774 - val_loss: 1.5190 - val_accuracy: 0.8984
# Epoch 267/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0791 - accuracy: 0.9742 - val_loss: 1.3470 - val_accuracy: 0.9079
# Epoch 268/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0581 - accuracy: 0.9784 - val_loss: 1.2721 - val_accuracy: 0.9175
# Epoch 269/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0541 - accuracy: 0.9788 - val_loss: 1.3712 - val_accuracy: 0.9111
# Epoch 270/500
# 89/89 [==============================] - 111s 1s/step - loss: 0.0534 - accuracy: 0.9791 - val_loss: 1.4313 - val_accuracy: 0.9111
# Epoch 271/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0535 - accuracy: 0.9791 - val_loss: 1.4068 - val_accuracy: 0.9175
# Epoch 272/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0531 - accuracy: 0.9788 - val_loss: 1.4140 - val_accuracy: 0.9143
# Epoch 273/500
# 89/89 [==============================] - 111s 1s/step - loss: 0.0529 - accuracy: 0.9791 - val_loss: 1.4466 - val_accuracy: 0.9143
# Epoch 274/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0529 - accuracy: 0.9784 - val_loss: 1.5233 - val_accuracy: 0.9111
# Epoch 275/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0535 - accuracy: 0.9788 - val_loss: 1.4586 - val_accuracy: 0.9143
# Epoch 276/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0530 - accuracy: 0.9784 - val_loss: 1.4883 - val_accuracy: 0.9175
# Epoch 277/500
# 89/89 [==============================] - 104s 1s/step - loss: 0.0533 - accuracy: 0.9791 - val_loss: 1.4933 - val_accuracy: 0.9175
# Epoch 278/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0529 - accuracy: 0.9781 - val_loss: 1.5544 - val_accuracy: 0.9175
# Epoch 279/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0531 - accuracy: 0.9784 - val_loss: 1.5483 - val_accuracy: 0.9175
# Epoch 280/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0529 - accuracy: 0.9788 - val_loss: 1.5454 - val_accuracy: 0.9143
# Epoch 281/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0529 - accuracy: 0.9795 - val_loss: 1.5113 - val_accuracy: 0.9175
# Epoch 282/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0529 - accuracy: 0.9791 - val_loss: 1.5959 - val_accuracy: 0.9143
# Epoch 283/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0530 - accuracy: 0.9781 - val_loss: 1.5277 - val_accuracy: 0.9143
# Epoch 284/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0532 - accuracy: 0.9788 - val_loss: 1.5532 - val_accuracy: 0.9175
# Epoch 285/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0530 - accuracy: 0.9784 - val_loss: 1.5799 - val_accuracy: 0.9175
# Epoch 286/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0534 - accuracy: 0.9781 - val_loss: 1.5581 - val_accuracy: 0.9143
# Epoch 287/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0529 - accuracy: 0.9795 - val_loss: 1.5657 - val_accuracy: 0.9175
# Epoch 288/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0532 - accuracy: 0.9784 - val_loss: 1.5102 - val_accuracy: 0.9175
# Epoch 289/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0529 - accuracy: 0.9784 - val_loss: 1.5871 - val_accuracy: 0.9206
# Epoch 290/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0528 - accuracy: 0.9784 - val_loss: 1.5389 - val_accuracy: 0.9206
# Epoch 291/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0529 - accuracy: 0.9788 - val_loss: 1.5749 - val_accuracy: 0.9175
# Epoch 292/500
# 89/89 [==============================] - 112s 1s/step - loss: 0.0531 - accuracy: 0.9791 - val_loss: 1.5448 - val_accuracy: 0.9175
# Epoch 293/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0529 - accuracy: 0.9795 - val_loss: 1.5244 - val_accuracy: 0.9175
# Epoch 294/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0530 - accuracy: 0.9795 - val_loss: 1.5709 - val_accuracy: 0.9143
# Epoch 295/500
# 89/89 [==============================] - 111s 1s/step - loss: 0.0531 - accuracy: 0.9791 - val_loss: 1.5879 - val_accuracy: 0.9175
# Epoch 296/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0530 - accuracy: 0.9788 - val_loss: 1.5695 - val_accuracy: 0.9175
# Epoch 297/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0530 - accuracy: 0.9781 - val_loss: 1.6565 - val_accuracy: 0.9175
# Epoch 298/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0529 - accuracy: 0.9795 - val_loss: 1.4064 - val_accuracy: 0.9175
# Epoch 299/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0534 - accuracy: 0.9791 - val_loss: 1.6230 - val_accuracy: 0.9206
# Epoch 300/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0530 - accuracy: 0.9784 - val_loss: 1.4186 - val_accuracy: 0.9175
# Epoch 301/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0532 - accuracy: 0.9788 - val_loss: 1.5972 - val_accuracy: 0.9238
# Epoch 302/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0530 - accuracy: 0.9788 - val_loss: 1.6189 - val_accuracy: 0.9206
# Epoch 303/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0526 - accuracy: 0.9784 - val_loss: 1.3979 - val_accuracy: 0.9175
# Epoch 304/500
# 89/89 [==============================] - 112s 1s/step - loss: 0.0773 - accuracy: 0.9749 - val_loss: 0.9498 - val_accuracy: 0.9048
# Epoch 305/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0826 - accuracy: 0.9724 - val_loss: 1.5333 - val_accuracy: 0.8921
# Epoch 306/500
# 89/89 [==============================] - 113s 1s/step - loss: 0.0604 - accuracy: 0.9770 - val_loss: 1.1458 - val_accuracy: 0.9048
# Epoch 307/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0556 - accuracy: 0.9784 - val_loss: 1.2032 - val_accuracy: 0.9238
# Epoch 308/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0536 - accuracy: 0.9791 - val_loss: 1.1290 - val_accuracy: 0.9143
# Epoch 309/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0535 - accuracy: 0.9788 - val_loss: 1.2539 - val_accuracy: 0.9143
# Epoch 310/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0531 - accuracy: 0.9788 - val_loss: 1.2741 - val_accuracy: 0.9143
# Epoch 311/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0534 - accuracy: 0.9788 - val_loss: 1.2061 - val_accuracy: 0.9111
# Epoch 312/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0535 - accuracy: 0.9795 - val_loss: 1.2750 - val_accuracy: 0.9079
# Epoch 313/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0534 - accuracy: 0.9788 - val_loss: 1.2842 - val_accuracy: 0.9111
# Epoch 314/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0528 - accuracy: 0.9784 - val_loss: 1.3249 - val_accuracy: 0.9111
# Epoch 315/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0528 - accuracy: 0.9791 - val_loss: 1.3109 - val_accuracy: 0.9111
# Epoch 316/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0530 - accuracy: 0.9781 - val_loss: 1.2993 - val_accuracy: 0.9079
# Epoch 317/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0533 - accuracy: 0.9788 - val_loss: 1.3363 - val_accuracy: 0.9111
# Epoch 318/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0531 - accuracy: 0.9784 - val_loss: 1.2923 - val_accuracy: 0.9111
# Epoch 319/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0529 - accuracy: 0.9784 - val_loss: 1.3326 - val_accuracy: 0.9111
# Epoch 320/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0528 - accuracy: 0.9788 - val_loss: 1.3558 - val_accuracy: 0.9111
# Epoch 321/500
# 89/89 [==============================] - 105s 1s/step - loss: 0.0534 - accuracy: 0.9791 - val_loss: 1.3417 - val_accuracy: 0.9111
# Epoch 322/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0527 - accuracy: 0.9795 - val_loss: 1.3995 - val_accuracy: 0.9111
# Epoch 323/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0532 - accuracy: 0.9784 - val_loss: 1.3924 - val_accuracy: 0.9111
# Epoch 324/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0529 - accuracy: 0.9791 - val_loss: 1.4193 - val_accuracy: 0.9111
# Epoch 325/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0529 - accuracy: 0.9784 - val_loss: 1.3621 - val_accuracy: 0.9111
# Epoch 326/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0530 - accuracy: 0.9791 - val_loss: 1.3620 - val_accuracy: 0.9111
# Epoch 327/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0526 - accuracy: 0.9781 - val_loss: 1.4484 - val_accuracy: 0.9111
# Epoch 328/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0546 - accuracy: 0.9784 - val_loss: 1.3876 - val_accuracy: 0.9079
# Epoch 329/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0531 - accuracy: 0.9795 - val_loss: 1.4264 - val_accuracy: 0.9143
# Epoch 330/500
# 89/89 [==============================] - 109s 1s/step - loss: 0.0531 - accuracy: 0.9781 - val_loss: 1.4360 - val_accuracy: 0.9111
# Epoch 331/500
# 89/89 [==============================] - 108s 1s/step - loss: 0.0526 - accuracy: 0.9795 - val_loss: 1.4976 - val_accuracy: 0.9079
# Epoch 332/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0532 - accuracy: 0.9788 - val_loss: 1.4713 - val_accuracy: 0.9079
# Epoch 333/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0571 - accuracy: 0.9781 - val_loss: 1.3164 - val_accuracy: 0.9143
# Epoch 334/500
# 89/89 [==============================] - 110s 1s/step - loss: 0.0537 - accuracy: 0.9788 - val_loss: 1.3646 - val_accuracy: 0.9206
# Epoch 335/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0528 - accuracy: 0.9791 - val_loss: 1.6735 - val_accuracy: 0.9111
# Epoch 336/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.1138 - accuracy: 0.9689 - val_loss: 2.0152 - val_accuracy: 0.8952
# Epoch 337/500
# 89/89 [==============================] - 104s 1s/step - loss: 0.0745 - accuracy: 0.9756 - val_loss: 1.6004 - val_accuracy: 0.9143
# Epoch 338/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0584 - accuracy: 0.9777 - val_loss: 1.4251 - val_accuracy: 0.9079
# Epoch 339/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0542 - accuracy: 0.9788 - val_loss: 1.4107 - val_accuracy: 0.9079
# Epoch 340/500
# 89/89 [==============================] - 106s 1s/step - loss: 0.0534 - accuracy: 0.9791 - val_loss: 1.4116 - val_accuracy: 0.9111
# Epoch 341/500
# 89/89 [==============================] - 103s 1s/step - loss: 0.0530 - accuracy: 0.9791 - val_loss: 1.4534 - val_accuracy: 0.9111
# Epoch 342/500
# 89/89 [==============================] - 107s 1s/step - loss: 0.0530 - accuracy: 0.9788 - val_loss: 1.4369 - val_accuracy: 0.9079
# Epoch 343/500
# 45/89 [==============>...............] - ETA: 50s - loss: 0.0480 - accuracy: 0.9799

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dd83d5eaf4d2> in <cell line: 2>()
#       1 # Evaluate the model
# ----> 2 test_loss, test_accuracy = model.evaluate(X_test, y_test)
#       3 print("Test Accuracy:", test_accuracy)
#
# NameError: name 'model' is not defined

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=500, validation_data=(X_val, y_val))

# Evaluate the model on the testing set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)

# %%
# Visualize training history (loss and accuracy over epochs)
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Make predictions on the testing set
predictions = model.predict(X_test)

# Visualize some predictions
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(X_test[i])
    plt.title("Predicted: {}, Actual: {}".format(np.argmax(predictions[i]), y_test[i]))
    plt.axis('off')
plt.show()
